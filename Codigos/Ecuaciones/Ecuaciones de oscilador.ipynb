# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.animation as anim

# %%
TMin, TMax, N = 0.,25., 201
t = np.linspace(TMin, TMax, N)
h = (TMax-TMin)/float(N-1)

# %%
r0 = np.array([1.0,0])

# %%
def df(x,b=1):
    return -b*x

# %%
def dfn(x, b=1, a=1):
    termino1=-b* (1/np.sqrt(a**2+np.power(x,2)))
    return x*termino1

# %%
def GetLeapFrog(r0,t,fun):
    
    N = len(t)
    h = t[1] - t[0]
    
    t1 = np.arange(TMin - 0.5*h, TMax - 0.5*h + h, h)
    
    x = np.zeros(N)
    v = np.zeros(N) # El inicializador

    x[0] = r0[0]
    v[0] = r0[1] - 0.5*h*fun(x[0])
    
    for i in range(1,N):
        
        v[i] = v[i-1] + h*fun(x[i-1])
        x[i] = x[i-1] + h*v[i]
    
    # Igualando los array
    X = np.array([])
    for i in range(len(x)-1):
        X = np.append(X,(x[i]+x[i+1])*0.5)

    V = v[1:]
    
    return X,V

# %%
x1, v1=  GetLeapFrog(r0,t, df)
x2, v2=  GetLeapFrog(r0,t, dfn)

# %%
fig0 = plt.figure(figsize=(10,5))
#Crear plots
ax = fig0.add_subplot(121)
ax1 = fig0.add_subplot(122)
#Graficar
ax.plot(t[1:],x1, '#fc600a',label='Aproximado')
ax.plot(t[1:],x2, '#337c99',label='Completo')
ax1.plot(t[1:],v1, '#fc600a',label='Aproximado')
ax1.plot(t[1:],v2, '#337c99',label='Completo')
#legends
ax.legend()
ax1.legend()
#Titulos
ax.set_title('Posicion')
ax1.set_title('Velocidad')
#Titulo ejes
ax.set_xlabel('t')
ax.set_ylabel('x')
ax1.set_xlabel('t')
ax1.set_ylabel('v')
#Guardar
plt.savefig('../../Images/osciladores')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27728/597717148.py in <module>
#       5 #Graficar
#       6 ax.plot(t[1:],x1, '#fc600a',label='Aproximado')
# ----> 7 ax.scatter(t[1:],x2, '#337c99',label='Completo')
#       8 ax1.plot(t[1:],v1, '#fc600a',label='Aproximado')
#       9 ax1.plot(t[1:],v2, '#337c99',label='Completo')
#
# c:\users\frawo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\frawo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# c:\users\frawo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4493                 offsets=offsets,
#    4494                 transOffset=kwargs.pop('transform', self.transData),
# -> 4495                 alpha=alpha
#    4496                 )
#    4497         collection.set_transform(mtransforms.IdentityTransform())
#
# c:\users\frawo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     953         super().__init__(**kwargs)
#     954         self.set_paths(paths)
# --> 955         self.set_sizes(sizes)
#     956         self.stale = True
#     957
#
# c:\users\frawo\appdata\local\programs\python\python37\lib\site-packages\matplotlib\collections.py in set_sizes(self, sizes, dpi)
#     920             self._sizes = np.asarray(sizes)
#     921             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 922             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     923             self._transforms[:, 0, 0] = scale
#     924             self._transforms[:, 1, 1] = scale
#
# TypeError: ufunc 'sqrt' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
